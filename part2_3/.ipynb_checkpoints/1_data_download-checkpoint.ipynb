# %%
import pandas as pd
import csv
import requests
import json
import re
import time
import os
from datetime import datetime, timedelta
import shutil
import xlsxwriter
import datetime
# !pip install geojson
import geojson
# Out:
# Collecting geojson
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: geojson
# Successfully installed geojson-3.2.0

# %% [markdown]
# # 1. Data Downloading

# %% [markdown]
# ## 1.1 Migration proportion data

# %%
# This dictionary maps city ID from the API to city names for filenames.
### If you need to fetch data for other cities, please change them here.

translation_table = {
    '440100': 'GuangZhou',
    '440300': 'ShenZhen',
    '440400': 'ZhuHai',
    '440600': 'FoShan',
    '440700': 'JiangMen',
    '441200': 'ZhaoQing',
    '441300': 'HuiZhou',
    '441900': 'DongGuan',
    '442000': 'ZhongShan',
}

# %%
class Types:
    """
    Store some data that we want to request.
    """
    
    data_type = {'cityrank'}

    dt = {'country',
          # 'province',
          'city'}
    
    ### If you need to fetch data for other cities, please change them here.
    region = {
        # Use Types.region.keys() to see which provinces are available;
        # Use Types.region["ID"] to check if it's a province or a city.
        '440100': 'city',
        '440300': 'city',
        '440400': 'city',
        '440600': 'city',
        '440700': 'city',
        '441200': 'city',
        '441300': 'city',
        '441900': 'city',
        '442000': 'city',
    }

    move_type = {# 'move_in',
                 'move_out'}

# %%
def generate_date_range(start_date_str:str, end_date_str:str):
    """
    Enter the dates on both ends and the output will include all dates including those two days.

    :param start_date_str: The start date in the 8-digit format of "yyyymmdd", e.g. "20220130".
    :param end_date_str: The end date in 8-digit format of "yyyymmdd", e.g. "20220131".
    :return: A list of date strings from start_date to end_date (inclusive),
             in the format "yyyymmdd".
    """
    # Convert the input date strings to datetime objects
    start_date = datetime.strptime(start_date_str, '%Y%m%d')
    end_date = datetime.strptime(end_date_str, '%Y%m%d')

    # Initialize the date list with the start date
    date_list = [start_date.strftime('%Y%m%d')]

    # Generate the date range
    current_date = start_date
    while current_date < end_date:
        current_date += timedelta(days=1)
        date_list.append(current_date.strftime('%Y%m%d'))

    return date_list

# %%
def get_timestamp():
    """
    Get current timestamp.

    :return: Timestamp with 13 digits
    """
    return str(int(time.time() * 1000))  # * 1000 to get millisecond timestamps

# %%
def get_lastdate():
    """
    Get the latest date that the current API has.

    :return: An 8-digit string, formatted as "yyyymmdd", such as “20201231”.
    """
    url = f'http://huiyan.baidu.com/migration/lastdate.jsonp'
    response = requests.get(url)
    json_data_match = re.search(r'{.*}', response.text)
    if json_data_match:
        json_data_str = json_data_match.group()

        # Decode JSON string, automatically handling Unicode characters
        json_data = json.loads(json_data_str)
        return_value = json_data['data']['lastdate']
        print(f"Successful acquisition of the latest API date：{return_value}")
        return return_value
    else:
        print('Failed to get latest API date!')

# %%
def download_and_convert_csv(data_type: str, dt: str, id: str, move_type: str, date: str, callback: str):
    """
    :param data_type: 'cityrank'
    :param dt: 'country'/'province'/'city'
    :param id: city ID，such as '440100'
    :param move_type: 'move_in' or 'move_out'
    :param date: data，formatted like '20230101'
    :param callback: 13-digit timestamp
    :return: Export CSV files directly under ./data/
    """

    # Get city names from translation_table
    city_name = translation_table.get(id, id)

    # Construct CSV filename
    csv_filename = f"./data/{city_name}_{move_type}_{date}.csv"

    # Construct the API request URL
    url = (
        f"http://huiyan.baidu.com/migration/cityrank.jsonp?"
        f"dt={dt}&id={id}&type={move_type}&date={date}"
        f"&callback=callback&_={callback}"
    )
    response = requests.get(url)

    # Extract JSON data using a regular expression
    json_data_match = re.search(r'{.*}', response.text)
    if not json_data_match:
        print(f"JSON data not matched: {url}")
        return

    json_data_str = json_data_match.group()
    json_data = json.loads(json_data_str)

    if json_data.get('errmsg') == 'SUCCESS':
        rows = json_data["data"].get("list", [])
        if not rows:
            print(f"{id}-{date} Empty")
            return

        # Export to a CSV file
        with open(csv_filename, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=rows[0].keys())
            writer.writeheader()
            writer.writerows(rows)

        print(f"CSV file exported to: {csv_filename}")
    else:
        print(f"The interface returns the error: {json_data.get('errmsg')}")

# %%
def get_data(region: str, data_type: str, move_type: str, date: str):
    """
    Get the migration data for the specified region, data_type, move_type, date and export to CSV.
    """
    timestamp = get_timestamp()
    
    # Print prompts, using either city names or raw numbers
    city_name = translation_table.get(region, region)
    print(f"Accessing {city_name}'s {data_type} ({move_type}) data，data={date} ...")
    
    download_and_convert_csv(
        data_type=data_type,
        dt=Types.region[region],  
        id=region,
        move_type=move_type,
        date=date,
        callback=str(timestamp) 
    )

# %%
def get_by_date(from_date, to_date, lastdate):
    # Convert a date string to a datetime object
    from_date_dt = datetime.strptime(from_date, '%Y%m%d')
    to_date_dt = datetime.strptime(to_date, '%Y%m%d')
    lastdate_dt = datetime.strptime(lastdate, '%Y%m%d')

    print("Checking the validity of date input")

    # Check if the start date is earlier than '20190112'
    earlydate = datetime(2019, 1, 12)
    if from_date_dt < earlydate:
        print("Your start date is earlier than the earliest date the API currently has. Already set the start date to the earliest date the API has and try to keep running.")
        from_date_dt = earlydate

    # Check if the end date is later than the latest date
    if to_date_dt > lastdate_dt:
        print("Your end date is later than the latest date the API currently has. Already set the end date to the latest date the API has and try to keep running.")
        to_date_dt = lastdate_dt

    # Check if start data 
    if from_date_dt > to_date_dt:
        print("Your start date needs to be earlier than your end date.")
        return

    print("Success!")

    # Convert to a string to generate a date range
    from_date = from_date_dt.strftime('%Y%m%d')
    to_date = to_date_dt.strftime('%Y%m%d')

    for date in generate_date_range(from_date, to_date):  # data
        for region in Types.region.keys():
            for move_type in Types.move_type:
                for data_type in Types.data_type:
                    get_data(region, data_type, move_type, date)
    print("Completed!")


if __name__ == "__main__":
    # Check if the file exists
    if not os.path.exists('data'):
        # If not, create a fle
        os.makedirs('data')
    lastdate = get_lastdate()  
    ### If you need to change the start and end dates, change them here
    get_by_date('20240101', '20241231', lastdate)
# Out:
# Successful acquisition of the latest API date：20250410
# Checking the validity of date input
# Success!
# Accessing GuangZhou's cityrank (move_out) data，data=20240101 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240101.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240101 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240101.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240101 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240101.csv
# Accessing FoShan's cityrank (move_out) data，data=20240101 ...
# CSV file exported to: ./data/FoShan_move_out_20240101.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240101 ...
# CSV file exported to: ./data/JiangMen_move_out_20240101.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240101 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240101.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240101 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240101.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240101 ...
# CSV file exported to: ./data/DongGuan_move_out_20240101.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240101 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240101.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240102 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240102.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240102 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240102.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240102 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240102.csv
# Accessing FoShan's cityrank (move_out) data，data=20240102 ...
# CSV file exported to: ./data/FoShan_move_out_20240102.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240102 ...
# CSV file exported to: ./data/JiangMen_move_out_20240102.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240102 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240102.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240102 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240102.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240102 ...
# CSV file exported to: ./data/DongGuan_move_out_20240102.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240102 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240102.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240103 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240103.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240103 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240103.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240103 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240103.csv
# Accessing FoShan's cityrank (move_out) data，data=20240103 ...
# CSV file exported to: ./data/FoShan_move_out_20240103.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240103 ...
# CSV file exported to: ./data/JiangMen_move_out_20240103.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240103 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240103.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240103 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240103.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240103 ...
# CSV file exported to: ./data/DongGuan_move_out_20240103.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240103 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240103.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240104 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240104.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240104 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240104.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240104 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240104.csv
# Accessing FoShan's cityrank (move_out) data，data=20240104 ...
# CSV file exported to: ./data/FoShan_move_out_20240104.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240104 ...
# CSV file exported to: ./data/JiangMen_move_out_20240104.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240104 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240104.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240104 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240104.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240104 ...
# CSV file exported to: ./data/DongGuan_move_out_20240104.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240104 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240104.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240105 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240105.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240105 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240105.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240105 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240105.csv
# Accessing FoShan's cityrank (move_out) data，data=20240105 ...
# CSV file exported to: ./data/FoShan_move_out_20240105.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240105 ...
# CSV file exported to: ./data/JiangMen_move_out_20240105.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240105 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240105.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240105 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240105.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240105 ...
# CSV file exported to: ./data/DongGuan_move_out_20240105.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240105 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240105.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240106 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240106.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240106 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240106.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240106 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240106.csv
# Accessing FoShan's cityrank (move_out) data，data=20240106 ...
# CSV file exported to: ./data/FoShan_move_out_20240106.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240106 ...
# CSV file exported to: ./data/JiangMen_move_out_20240106.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240106 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240106.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240106 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240106.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240106 ...
# CSV file exported to: ./data/DongGuan_move_out_20240106.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240106 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240106.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240107 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240107.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240107 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240107.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240107 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240107.csv
# Accessing FoShan's cityrank (move_out) data，data=20240107 ...
# CSV file exported to: ./data/FoShan_move_out_20240107.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240107 ...
# CSV file exported to: ./data/JiangMen_move_out_20240107.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240107 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240107.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240107 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240107.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240107 ...
# CSV file exported to: ./data/DongGuan_move_out_20240107.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240107 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240107.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240108 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240108.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240108 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240108.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240108 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240108.csv
# Accessing FoShan's cityrank (move_out) data，data=20240108 ...
# CSV file exported to: ./data/FoShan_move_out_20240108.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240108 ...
# CSV file exported to: ./data/JiangMen_move_out_20240108.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240108 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240108.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240108 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240108.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240108 ...
# CSV file exported to: ./data/DongGuan_move_out_20240108.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240108 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240108.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240109 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240109.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240109 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240109.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240109 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240109.csv
# Accessing FoShan's cityrank (move_out) data，data=20240109 ...
# CSV file exported to: ./data/FoShan_move_out_20240109.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240109 ...
# CSV file exported to: ./data/JiangMen_move_out_20240109.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240109 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240109.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240109 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240109.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240109 ...
# CSV file exported to: ./data/DongGuan_move_out_20240109.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240109 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240109.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240110 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240110.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240110 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240110.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240110 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240110.csv
# Accessing FoShan's cityrank (move_out) data，data=20240110 ...
# CSV file exported to: ./data/FoShan_move_out_20240110.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240110 ...
# CSV file exported to: ./data/JiangMen_move_out_20240110.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240110 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240110.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240110 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240110.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240110 ...
# CSV file exported to: ./data/DongGuan_move_out_20240110.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240110 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240110.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240111 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240111.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240111 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240111.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240111 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240111.csv
# Accessing FoShan's cityrank (move_out) data，data=20240111 ...
# CSV file exported to: ./data/FoShan_move_out_20240111.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240111 ...
# CSV file exported to: ./data/JiangMen_move_out_20240111.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240111 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240111.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240111 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240111.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240111 ...
# CSV file exported to: ./data/DongGuan_move_out_20240111.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240111 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240111.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240112 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240112.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240112 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240112.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240112 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240112.csv
# Accessing FoShan's cityrank (move_out) data，data=20240112 ...
# CSV file exported to: ./data/FoShan_move_out_20240112.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240112 ...
# CSV file exported to: ./data/JiangMen_move_out_20240112.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240112 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240112.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240112 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240112.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240112 ...
# CSV file exported to: ./data/DongGuan_move_out_20240112.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240112 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240112.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240113 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240113.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240113 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240113.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240113 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240113.csv
# Accessing FoShan's cityrank (move_out) data，data=20240113 ...
# CSV file exported to: ./data/FoShan_move_out_20240113.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240113 ...
# CSV file exported to: ./data/JiangMen_move_out_20240113.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240113 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240113.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240113 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240113.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240113 ...
# CSV file exported to: ./data/DongGuan_move_out_20240113.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240113 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240113.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240114 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240114.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240114 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240114.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240114 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240114.csv
# Accessing FoShan's cityrank (move_out) data，data=20240114 ...
# CSV file exported to: ./data/FoShan_move_out_20240114.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240114 ...
# CSV file exported to: ./data/JiangMen_move_out_20240114.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240114 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240114.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240114 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240114.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240114 ...
# CSV file exported to: ./data/DongGuan_move_out_20240114.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240114 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240114.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240115 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240115.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240115 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240115.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240115 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240115.csv
# Accessing FoShan's cityrank (move_out) data，data=20240115 ...
# CSV file exported to: ./data/FoShan_move_out_20240115.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240115 ...
# CSV file exported to: ./data/JiangMen_move_out_20240115.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240115 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240115.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240115 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240115.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240115 ...
# CSV file exported to: ./data/DongGuan_move_out_20240115.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240115 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240115.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240116 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240116.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240116 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240116.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240116 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240116.csv
# Accessing FoShan's cityrank (move_out) data，data=20240116 ...
# CSV file exported to: ./data/FoShan_move_out_20240116.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240116 ...
# CSV file exported to: ./data/JiangMen_move_out_20240116.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240116 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240116.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240116 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240116.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240116 ...
# CSV file exported to: ./data/DongGuan_move_out_20240116.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240116 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240116.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240117 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240117.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240117 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240117.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240117 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240117.csv
# Accessing FoShan's cityrank (move_out) data，data=20240117 ...
# CSV file exported to: ./data/FoShan_move_out_20240117.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240117 ...
# CSV file exported to: ./data/JiangMen_move_out_20240117.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240117 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240117.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240117 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240117.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240117 ...
# CSV file exported to: ./data/DongGuan_move_out_20240117.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240117 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240117.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240118 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240118.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240118 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240118.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240118 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240118.csv
# Accessing FoShan's cityrank (move_out) data，data=20240118 ...
# CSV file exported to: ./data/FoShan_move_out_20240118.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240118 ...
# CSV file exported to: ./data/JiangMen_move_out_20240118.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240118 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240118.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240118 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240118.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240118 ...
# CSV file exported to: ./data/DongGuan_move_out_20240118.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240118 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240118.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240119 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240119.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240119 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240119.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240119 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240119.csv
# Accessing FoShan's cityrank (move_out) data，data=20240119 ...
# CSV file exported to: ./data/FoShan_move_out_20240119.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240119 ...
# CSV file exported to: ./data/JiangMen_move_out_20240119.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240119 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240119.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240119 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240119.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240119 ...
# CSV file exported to: ./data/DongGuan_move_out_20240119.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240119 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240119.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240120 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240120.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240120 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240120.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240120 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240120.csv
# Accessing FoShan's cityrank (move_out) data，data=20240120 ...
# CSV file exported to: ./data/FoShan_move_out_20240120.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240120 ...
# CSV file exported to: ./data/JiangMen_move_out_20240120.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240120 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240120.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240120 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240120.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240120 ...
# CSV file exported to: ./data/DongGuan_move_out_20240120.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240120 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240120.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240121 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240121.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240121 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240121.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240121 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240121.csv
# Accessing FoShan's cityrank (move_out) data，data=20240121 ...
# CSV file exported to: ./data/FoShan_move_out_20240121.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240121 ...
# CSV file exported to: ./data/JiangMen_move_out_20240121.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240121 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240121.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240121 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240121.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240121 ...
# CSV file exported to: ./data/DongGuan_move_out_20240121.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240121 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240121.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240122 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240122.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240122 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240122.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240122 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240122.csv
# Accessing FoShan's cityrank (move_out) data，data=20240122 ...
# CSV file exported to: ./data/FoShan_move_out_20240122.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240122 ...
# CSV file exported to: ./data/JiangMen_move_out_20240122.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240122 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240122.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240122 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240122.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240122 ...
# CSV file exported to: ./data/DongGuan_move_out_20240122.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240122 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240122.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240123 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240123.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240123 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240123.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240123 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240123.csv
# Accessing FoShan's cityrank (move_out) data，data=20240123 ...
# CSV file exported to: ./data/FoShan_move_out_20240123.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240123 ...
# CSV file exported to: ./data/JiangMen_move_out_20240123.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240123 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240123.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240123 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240123.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240123 ...
# CSV file exported to: ./data/DongGuan_move_out_20240123.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240123 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240123.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240124 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240124.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240124 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240124.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240124 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240124.csv
# Accessing FoShan's cityrank (move_out) data，data=20240124 ...
# CSV file exported to: ./data/FoShan_move_out_20240124.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240124 ...
# CSV file exported to: ./data/JiangMen_move_out_20240124.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240124 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240124.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240124 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240124.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240124 ...
# CSV file exported to: ./data/DongGuan_move_out_20240124.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240124 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240124.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240125 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240125.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240125 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240125.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240125 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240125.csv
# Accessing FoShan's cityrank (move_out) data，data=20240125 ...
# CSV file exported to: ./data/FoShan_move_out_20240125.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240125 ...
# CSV file exported to: ./data/JiangMen_move_out_20240125.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240125 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240125.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240125 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240125.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240125 ...
# CSV file exported to: ./data/DongGuan_move_out_20240125.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240125 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240125.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240126 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240126.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240126 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240126.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240126 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240126.csv
# Accessing FoShan's cityrank (move_out) data，data=20240126 ...
# CSV file exported to: ./data/FoShan_move_out_20240126.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240126 ...
# CSV file exported to: ./data/JiangMen_move_out_20240126.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240126 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240126.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240126 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240126.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240126 ...
# CSV file exported to: ./data/DongGuan_move_out_20240126.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240126 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240126.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240127 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240127.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240127 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240127.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240127 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240127.csv
# Accessing FoShan's cityrank (move_out) data，data=20240127 ...
# CSV file exported to: ./data/FoShan_move_out_20240127.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240127 ...
# CSV file exported to: ./data/JiangMen_move_out_20240127.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240127 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240127.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240127 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240127.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240127 ...
# CSV file exported to: ./data/DongGuan_move_out_20240127.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240127 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240127.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240128 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240128.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240128 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240128.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240128 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240128.csv
# Accessing FoShan's cityrank (move_out) data，data=20240128 ...
# CSV file exported to: ./data/FoShan_move_out_20240128.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240128 ...
# CSV file exported to: ./data/JiangMen_move_out_20240128.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240128 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240128.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240128 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240128.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240128 ...
# CSV file exported to: ./data/DongGuan_move_out_20240128.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240128 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240128.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240129 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240129.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240129 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240129.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240129 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240129.csv
# Accessing FoShan's cityrank (move_out) data，data=20240129 ...
# CSV file exported to: ./data/FoShan_move_out_20240129.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240129 ...
# CSV file exported to: ./data/JiangMen_move_out_20240129.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240129 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240129.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240129 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240129.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240129 ...
# CSV file exported to: ./data/DongGuan_move_out_20240129.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240129 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240129.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240130 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240130.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240130 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240130.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240130 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240130.csv
# Accessing FoShan's cityrank (move_out) data，data=20240130 ...
# CSV file exported to: ./data/FoShan_move_out_20240130.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240130 ...
# CSV file exported to: ./data/JiangMen_move_out_20240130.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240130 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240130.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240130 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240130.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240130 ...
# CSV file exported to: ./data/DongGuan_move_out_20240130.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240130 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240130.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240131 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240131.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240131 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240131.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240131 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240131.csv
# Accessing FoShan's cityrank (move_out) data，data=20240131 ...
# CSV file exported to: ./data/FoShan_move_out_20240131.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240131 ...
# CSV file exported to: ./data/JiangMen_move_out_20240131.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240131 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240131.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240131 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240131.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240131 ...
# CSV file exported to: ./data/DongGuan_move_out_20240131.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240131 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240131.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240201 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240201.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240201 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240201.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240201 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240201.csv
# Accessing FoShan's cityrank (move_out) data，data=20240201 ...
# CSV file exported to: ./data/FoShan_move_out_20240201.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240201 ...
# CSV file exported to: ./data/JiangMen_move_out_20240201.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240201 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240201.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240201 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240201.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240201 ...
# CSV file exported to: ./data/DongGuan_move_out_20240201.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240201 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240201.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240202 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240202.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240202 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240202.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240202 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240202.csv
# Accessing FoShan's cityrank (move_out) data，data=20240202 ...
# CSV file exported to: ./data/FoShan_move_out_20240202.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240202 ...
# CSV file exported to: ./data/JiangMen_move_out_20240202.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240202 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240202.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240202 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240202.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240202 ...
# CSV file exported to: ./data/DongGuan_move_out_20240202.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240202 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240202.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240203 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240203.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240203 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240203.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240203 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240203.csv
# Accessing FoShan's cityrank (move_out) data，data=20240203 ...
# CSV file exported to: ./data/FoShan_move_out_20240203.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240203 ...
# CSV file exported to: ./data/JiangMen_move_out_20240203.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240203 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240203.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240203 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240203.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240203 ...
# CSV file exported to: ./data/DongGuan_move_out_20240203.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240203 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240203.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240204 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240204.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240204 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240204.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240204 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240204.csv
# Accessing FoShan's cityrank (move_out) data，data=20240204 ...
# CSV file exported to: ./data/FoShan_move_out_20240204.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240204 ...
# CSV file exported to: ./data/JiangMen_move_out_20240204.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240204 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240204.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240204 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240204.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240204 ...
# CSV file exported to: ./data/DongGuan_move_out_20240204.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240204 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240204.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240205 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240205.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240205 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240205.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240205 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240205.csv
# Accessing FoShan's cityrank (move_out) data，data=20240205 ...
# CSV file exported to: ./data/FoShan_move_out_20240205.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240205 ...
# CSV file exported to: ./data/JiangMen_move_out_20240205.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240205 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240205.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240205 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240205.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240205 ...
# CSV file exported to: ./data/DongGuan_move_out_20240205.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240205 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240205.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240206 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240206.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240206 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240206.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240206 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240206.csv
# Accessing FoShan's cityrank (move_out) data，data=20240206 ...
# CSV file exported to: ./data/FoShan_move_out_20240206.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240206 ...
# CSV file exported to: ./data/JiangMen_move_out_20240206.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240206 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240206.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240206 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240206.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240206 ...
# CSV file exported to: ./data/DongGuan_move_out_20240206.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240206 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240206.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240207 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240207.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240207 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240207.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240207 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240207.csv
# Accessing FoShan's cityrank (move_out) data，data=20240207 ...
# CSV file exported to: ./data/FoShan_move_out_20240207.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240207 ...
# CSV file exported to: ./data/JiangMen_move_out_20240207.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240207 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240207.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240207 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240207.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240207 ...
# CSV file exported to: ./data/DongGuan_move_out_20240207.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240207 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240207.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240208 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240208.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240208 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240208.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240208 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240208.csv
# Accessing FoShan's cityrank (move_out) data，data=20240208 ...
# CSV file exported to: ./data/FoShan_move_out_20240208.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240208 ...
# CSV file exported to: ./data/JiangMen_move_out_20240208.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240208 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240208.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240208 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240208.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240208 ...
# CSV file exported to: ./data/DongGuan_move_out_20240208.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240208 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240208.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240209 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240209.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240209 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240209.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240209 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240209.csv
# Accessing FoShan's cityrank (move_out) data，data=20240209 ...
# CSV file exported to: ./data/FoShan_move_out_20240209.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240209 ...
# CSV file exported to: ./data/JiangMen_move_out_20240209.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240209 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240209.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240209 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240209.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240209 ...
# CSV file exported to: ./data/DongGuan_move_out_20240209.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240209 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240209.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240210 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240210.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240210 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240210.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240210 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240210.csv
# Accessing FoShan's cityrank (move_out) data，data=20240210 ...
# CSV file exported to: ./data/FoShan_move_out_20240210.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240210 ...
# CSV file exported to: ./data/JiangMen_move_out_20240210.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240210 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240210.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240210 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240210.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240210 ...
# CSV file exported to: ./data/DongGuan_move_out_20240210.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240210 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240210.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240211 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240211.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240211 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240211.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240211 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240211.csv
# Accessing FoShan's cityrank (move_out) data，data=20240211 ...
# CSV file exported to: ./data/FoShan_move_out_20240211.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240211 ...
# CSV file exported to: ./data/JiangMen_move_out_20240211.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240211 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240211.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240211 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240211.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240211 ...
# CSV file exported to: ./data/DongGuan_move_out_20240211.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240211 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240211.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240212 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240212.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240212 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240212.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240212 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240212.csv
# Accessing FoShan's cityrank (move_out) data，data=20240212 ...
# CSV file exported to: ./data/FoShan_move_out_20240212.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240212 ...
# CSV file exported to: ./data/JiangMen_move_out_20240212.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240212 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240212.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240212 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240212.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240212 ...
# CSV file exported to: ./data/DongGuan_move_out_20240212.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240212 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240212.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240213 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240213.csv
# ...
# Accessing DongGuan's cityrank (move_out) data，data=20240615 ...
# CSV file exported to: ./data/DongGuan_move_out_20240615.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240615 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240615.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240616 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240616.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240616 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240616.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240616 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240616.csv
# Accessing FoShan's cityrank (move_out) data，data=20240616 ...
# CSV file exported to: ./data/FoShan_move_out_20240616.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240616 ...
# CSV file exported to: ./data/JiangMen_move_out_20240616.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240616 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240616.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240616 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240616.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240616 ...
# CSV file exported to: ./data/DongGuan_move_out_20240616.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240616 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240616.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240617 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240617.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240617 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240617.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240617 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240617.csv
# Accessing FoShan's cityrank (move_out) data，data=20240617 ...
# CSV file exported to: ./data/FoShan_move_out_20240617.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240617 ...
# CSV file exported to: ./data/JiangMen_move_out_20240617.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240617 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240617.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240617 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240617.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240617 ...
# CSV file exported to: ./data/DongGuan_move_out_20240617.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240617 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240617.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240618 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240618.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240618 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240618.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240618 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240618.csv
# Accessing FoShan's cityrank (move_out) data，data=20240618 ...
# CSV file exported to: ./data/FoShan_move_out_20240618.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240618 ...
# CSV file exported to: ./data/JiangMen_move_out_20240618.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240618 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240618.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240618 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240618.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240618 ...
# CSV file exported to: ./data/DongGuan_move_out_20240618.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240618 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240618.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240619 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240619.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240619 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240619.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240619 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240619.csv
# Accessing FoShan's cityrank (move_out) data，data=20240619 ...
# CSV file exported to: ./data/FoShan_move_out_20240619.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240619 ...
# CSV file exported to: ./data/JiangMen_move_out_20240619.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240619 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240619.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240619 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240619.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240619 ...
# CSV file exported to: ./data/DongGuan_move_out_20240619.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240619 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240619.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240620 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240620.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240620 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240620.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240620 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240620.csv
# Accessing FoShan's cityrank (move_out) data，data=20240620 ...
# CSV file exported to: ./data/FoShan_move_out_20240620.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240620 ...
# CSV file exported to: ./data/JiangMen_move_out_20240620.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240620 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240620.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240620 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240620.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240620 ...
# CSV file exported to: ./data/DongGuan_move_out_20240620.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240620 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240620.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240621 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240621.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240621 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240621.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240621 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240621.csv
# Accessing FoShan's cityrank (move_out) data，data=20240621 ...
# CSV file exported to: ./data/FoShan_move_out_20240621.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240621 ...
# CSV file exported to: ./data/JiangMen_move_out_20240621.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240621 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240621.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240621 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240621.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240621 ...
# CSV file exported to: ./data/DongGuan_move_out_20240621.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240621 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240621.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240622 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240622.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240622 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240622.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240622 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240622.csv
# Accessing FoShan's cityrank (move_out) data，data=20240622 ...
# CSV file exported to: ./data/FoShan_move_out_20240622.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240622 ...
# CSV file exported to: ./data/JiangMen_move_out_20240622.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240622 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240622.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240622 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240622.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240622 ...
# CSV file exported to: ./data/DongGuan_move_out_20240622.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240622 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240622.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240623 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240623.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240623 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240623.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240623 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240623.csv
# Accessing FoShan's cityrank (move_out) data，data=20240623 ...
# CSV file exported to: ./data/FoShan_move_out_20240623.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240623 ...
# CSV file exported to: ./data/JiangMen_move_out_20240623.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240623 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240623.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240623 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240623.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240623 ...
# CSV file exported to: ./data/DongGuan_move_out_20240623.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240623 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240623.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240624 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240624.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240624 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240624.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240624 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240624.csv
# Accessing FoShan's cityrank (move_out) data，data=20240624 ...
# CSV file exported to: ./data/FoShan_move_out_20240624.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240624 ...
# CSV file exported to: ./data/JiangMen_move_out_20240624.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240624 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240624.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240624 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240624.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240624 ...
# CSV file exported to: ./data/DongGuan_move_out_20240624.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240624 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240624.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240625 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240625.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240625 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240625.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240625 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240625.csv
# Accessing FoShan's cityrank (move_out) data，data=20240625 ...
# CSV file exported to: ./data/FoShan_move_out_20240625.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240625 ...
# CSV file exported to: ./data/JiangMen_move_out_20240625.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240625 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240625.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240625 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240625.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240625 ...
# CSV file exported to: ./data/DongGuan_move_out_20240625.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240625 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240625.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240626 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240626.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240626 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240626.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240626 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240626.csv
# Accessing FoShan's cityrank (move_out) data，data=20240626 ...
# CSV file exported to: ./data/FoShan_move_out_20240626.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240626 ...
# CSV file exported to: ./data/JiangMen_move_out_20240626.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240626 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240626.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240626 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240626.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240626 ...
# CSV file exported to: ./data/DongGuan_move_out_20240626.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240626 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240626.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240627 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240627.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240627 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240627.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240627 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240627.csv
# Accessing FoShan's cityrank (move_out) data，data=20240627 ...
# CSV file exported to: ./data/FoShan_move_out_20240627.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240627 ...
# CSV file exported to: ./data/JiangMen_move_out_20240627.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240627 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240627.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240627 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240627.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240627 ...
# CSV file exported to: ./data/DongGuan_move_out_20240627.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240627 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240627.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240628 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240628.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240628 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240628.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240628 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240628.csv
# Accessing FoShan's cityrank (move_out) data，data=20240628 ...
# CSV file exported to: ./data/FoShan_move_out_20240628.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240628 ...
# CSV file exported to: ./data/JiangMen_move_out_20240628.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240628 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240628.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240628 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240628.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240628 ...
# CSV file exported to: ./data/DongGuan_move_out_20240628.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240628 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240628.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240629 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240629.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240629 ...
# CSV file exported to: ./data/ShenZhen_move_out_20240629.csv
# Accessing ZhuHai's cityrank (move_out) data，data=20240629 ...
# CSV file exported to: ./data/ZhuHai_move_out_20240629.csv
# Accessing FoShan's cityrank (move_out) data，data=20240629 ...
# CSV file exported to: ./data/FoShan_move_out_20240629.csv
# Accessing JiangMen's cityrank (move_out) data，data=20240629 ...
# CSV file exported to: ./data/JiangMen_move_out_20240629.csv
# Accessing ZhaoQing's cityrank (move_out) data，data=20240629 ...
# CSV file exported to: ./data/ZhaoQing_move_out_20240629.csv
# Accessing HuiZhou's cityrank (move_out) data，data=20240629 ...
# CSV file exported to: ./data/HuiZhou_move_out_20240629.csv
# Accessing DongGuan's cityrank (move_out) data，data=20240629 ...
# CSV file exported to: ./data/DongGuan_move_out_20240629.csv
# Accessing ZhongShan's cityrank (move_out) data，data=20240629 ...
# CSV file exported to: ./data/ZhongShan_move_out_20240629.csv
# Accessing GuangZhou's cityrank (move_out) data，data=20240630 ...
# CSV file exported to: ./data/GuangZhou_move_out_20240630.csv
# Accessing ShenZhen's cityrank (move_out) data，data=20240630 ...

# %% [markdown]
# ## 1.2 Migration index data

# %%
# This dictionary maps city ID from the API to city names for filenames.
### If you need to fetch data for other cities, please change them here.

CitiesCode = {'GuangZhou':440100, 'ShenZhen':440300,'ZhuHai':440400, 
              'FoShan':440600,'JiangMen':440700, 'ZhaoQing':441200,
              'HuiZhou':441300, 'DongGuan':441900, 'ZhongShan':442000,}

# %%
def migration_index(FileTittle, classname, direction, CodeDict):
    # if direction == 'in':
        # nameofdire = 'move_in'
    if direction == 'out':
        nameofdire = 'move_out'

    output_folder = "data/1_2_index_raw"
    os.makedirs(output_folder, exist_ok=True) 
    save_path = os.path.join(output_folder, f"{FileTittle}_{nameofdire}_index_all_years.xlsx")
    workbook = xlsxwriter.Workbook(save_path)
    worksheet = workbook.add_worksheet('Sheet')

    CitiesOrder = {}  # Empty dictionary for storing city numbers
    worksheet.write(0, 0, 'City Code')  # Write to header
    worksheet.write(0, 1, 'City Name')  # Write to header
    times = 1
    for key, value in CodeDict.items():
        worksheet.write(times, 0, str(value))  # Write to city code
        worksheet.write(times, 1, str(key))  # Write to city name
        CitiesOrder[str(key)] = times  # Write to dictionary for storing city numbers
        times += 1

    for Area, Code in CodeDict.items():
        url = f'http://huiyan.baidu.com/migration/historycurve.json?dt={classname}&id={Code}&type=move_{direction}'
        print(f'{Area}: {url}')
        response = requests.get(url, timeout=2)  # request
        time.sleep(3)
        print(response.text)  # Chech if JSON is valid
        data_dict = response.json()  # Parsing JSON
        if data_dict['errmsg'] == 'SUCCESS':
            data_list = data_dict['data']['list']
            counter_date = 2  # Date counter
            dateList = []
            for date, index in data_list.items():
                dateList.append(date)  # Sort by date
            dateList.sort()
            for date in dateList:
                index = data_list[date]
                worksheet.write(0, counter_date, float(date))
                worksheet.write(CitiesOrder[str(Area)], counter_date, float(index))
                counter_date += 1  # Date counter + 1
        else:
            print('Error')
    workbook.close()

quanguo = {'whole country': 0}  # Country Code

if __name__ == "__main__":
    # migration_index('city', 'city', 'in', CitiesCode)
    migration_index('city', 'city', 'out', CitiesCode)
    print('Completed!')
# Out:
# GuangZhou: http://huiyan.baidu.com/migration/historycurve.json?dt=city&id=440100&type=move_out
#
# {"errno":0,"errmsg":"SUCCESS","data":{"list":{"20190112":10.976148,"20190113":9.3407256,"20190114":9.3356388,"20190115":8.66457,"20190116":9.29394,"20190117":9.6909048,"20190118":9.9609264,"20190119":11.75634,"20190120":10.853514,"20190121":11.5344,"20190122":11.9813904,"20190123":12.9839112,"20190124":13.4913924,"20190125":14.4756396,"20190126":18.0603108,"20190127":17.7778476,"20190128":18.0008568,"20190129":17.0088012,"20190130":16.0237764,"20190131":16.361676,"20190201":17.5477428,"20190202":16.5084804,"20190203":14.2816284,"20190204":11.4904656,"20190205":7.7750604,"20190206":9.8193384,"20190207":10.2669444,"20190208":9.0518796,"20190209":7.7014476,"20190210":6.8878512,"20190211":6.3177732,"20190212":6.0326856,"20190213":6.0744816,"20190214":6.3319644,"20190215":6.3365004,"20190216":7.8240816,"20190217":6.9613344,"20190218":6.89553,"20190219":6.2445492,"20190220":6.107724,"20190221":6.0220908,"20190222":6.3240912,"20190223":8.6273748,"20190224":8.2904796,"20190225":7.56216,"20190226":6.8235372,"20190227":7.6605264,"20190228":9.7802316,"20190301":8.4284712,"20190302":10.7190216,"20190303":8.8266996,"20190304":9.0201276,"20190305":7.5708432,"20190306":7.5587256,"20190307":7.6429332,"20190308":8.443926,"20190309":9.8581536,"20230104":9.8744184,"20230105":10.2376548,"20230106":11.417436,"20230107":14.1823224,"20230108":12.6899136,"20230109":12.888072,"20230110":13.6340496,"20230111":15.0266016,"20230112":14.8860828,"20230113":15.8625864,"20230114":20.425446,"20230115":19.2909276,"20230116":18.5537304,"20230117":18.75069,"20230118":19.3948344,"20230119":19.9795896,"20230120":17.11044,"20230121":13.170438,"20230122":9.129672,"20230123":12.6265716,"20230124":12.2532264,"20230125":10.4531148,"20230126":9.0244368,"20230127":8.197524,"20230128":7.1296524,"20230129":7.3808496,"20230130":7.5178368,"20230131":7.8285204,"20230201":8.3171772,"20230202":8.3957472,"20230203":9.1780452,"20230204":11.9404044,"20230205":9.400212,"20230206":10.140714,"20230207":8.8400484,"20230208":8.9481672,"20230209":9.2249928,"20230210":10.4916708,"20230211":14.7942936,"20230212":11.5504704,"20230213":11.8852272,"20230214":10.4033484,"20230215":10.5328836,"20230216":10.7216136,"20230217":11.818062,"20230218":16.1195184,"20230317":13.4693604,"20230318":18.2730492,"20230319":13.6062504,"20230320":13.5047088,"20230321":11.2604904,"20230322":10.7008776,"20230323":10.7022708,"20230324":12.1194468,"20230325":16.0993656,"20230326":11.4083316,"20230327":11.8155024,"20230328":10.4948136,"20230329":10.7479224,"20230330":11.4266376,"20230331":14.6532888,"20230401":21.1958856,"20230402":14.835474,"20230403":15.6879504,"20230404":16.5591864,"20230405":15.7109868,"20230406":10.0805472,"20230407":10.8760644,"20230408":15.3806688,"20230409":11.162934,"20230410":11.9945448,"20230411":10.6806924,"20230412":10.4510088,"20230413":10.6573644,"20230414":12.4397532,"20230415":16.7400432,"20230416":13.0583988,"20230417":13.39497,"20230418":11.3486184,"20230419":10.600146,"20230420":11.1825684,"20230421":11.8165716,"20230422":12.8759544,"20230423":11.8683792,"20230424":11.752452,"20230425":10.6768692,"20230426":11.44449,"20230427":12.7646928,"20230428":18.6938928,"20230429":35.218476,"20230430":32.561352,"20230501":28.1896848,"20230502":18.7426548,"20230503":15.7743936,"20230504":13.0927752,"20230505":10.2508092,"20230506":10.8977076,"20240123":10.982628,"20240124":11.4730344,"20240125":12.1348044,"20240126":14.2944588,"20240127":17.39556,"20240128":15.0598116,"20240129":15.6868164,"20240130":15.6518568,"20240131":16.1187732,"20240201":19.092186,"20240202":18.2113272,"20240203":20.0282544,"20240204":18.850644,"20240205":18.71748,"20240206":19.410516,"20240207":19.4151816,"20240208":17.6527188,"20240209":14.4321264,"20240210":9.513288,"20240211":13.2437268,"20240212":12.9735432,"20240213":11.4921828,"20240214":10.1120076,"20240215":9.4082148,"20240216":8.4292164,"20240217":8.1173664,"20240218":7.4582532,"20240219":7.1208072,"20240220":6.99192,"20240221":7.3299816,"20240222":7.50779 ...
# ShenZhen: http://huiyan.baidu.com/migration/historycurve.json?dt=city&id=440300&type=move_out
#
# {"errno":0,"errmsg":"SUCCESS","data":{"list":{"20190112":9.3351852,"20190113":8.2029996,"20190114":7.8272892,"20190115":6.7750992,"20190116":7.0771968,"20190117":7.43094,"20190118":7.6412484,"20190119":10.1525724,"20190120":9.6347232,"20190121":9.9261288,"20190122":9.8083224,"20190123":10.8651132,"20190124":11.572308,"20190125":12.9449664,"20190126":18.570384,"20190127":20.4308892,"20190128":20.4845436,"20190129":19.2438504,"20190130":19.655136,"20190131":20.756574,"20190201":21.2322384,"20190202":18.0986724,"20190203":14.297958,"20190204":11.2041792,"20190205":6.265674,"20190206":7.67961,"20190207":6.67116,"20190208":5.690736,"20190209":4.8056652,"20190210":4.4908344,"20190211":4.47606,"20190212":4.3482744,"20190213":4.487238,"20190214":4.8469104,"20190215":5.028804,"20190216":6.8241528,"20190217":6.0673536,"20190218":6.1765092,"20190219":5.2748496,"20190220":5.189832,"20190221":5.2222644,"20190222":5.4967572,"20190223":8.0788752,"20190224":7.570422,"20190225":6.6527244,"20190226":5.8301208,"20190227":6.5027772,"20190228":8.2394172,"20190301":7.092522,"20190302":9.8170056,"20190303":8.121384,"20190304":7.973316,"20190305":6.4870956,"20190306":6.3724968,"20190307":6.2665164,"20190308":6.8980572,"20190309":9.064224,"20230104":9.2065572,"20230105":9.4095432,"20230106":10.4756976,"20230107":13.689,"20230108":12.4737732,"20230109":12.488094,"20230110":12.922092,"20230111":15.024528,"20230112":15.843762,"20230113":18.106578,"20230114":26.3807604,"20230115":26.96814,"20230116":24.2095716,"20230117":23.1373908,"20230118":22.474746,"20230119":21.5678376,"20230120":17.2246176,"20230121":13.1994036,"20230122":6.6979224,"20230123":9.5386248,"20230124":7.2283104,"20230125":5.8869504,"20230126":5.0949648,"20230127":4.9841568,"20230128":4.7811708,"20230129":5.0405652,"20230130":5.4838944,"20230131":5.9231412,"20230201":6.5376396,"20230202":6.7479804,"20230203":7.6053168,"20230204":11.1077244,"20230205":8.7930684,"20230206":9.0982764,"20230207":7.5353652,"20230208":7.6307508,"20230209":7.843068,"20230210":8.9051076,"20230211":13.8813912,"20230212":10.440576,"20230213":10.6149204,"20230214":8.7419088,"20230215":8.9620344,"20230216":9.2670156,"20230217":10.3010616,"20230218":15.8212116,"20230317":11.190474,"20230318":17.247168,"20230319":11.8287216,"20230320":11.6408664,"20230321":9.261864,"20230322":8.9882136,"20230323":9.2912832,"20230324":10.6955316,"20230325":15.6881124,"20230326":9.913428,"20230327":10.6564572,"20230328":8.8403076,"20230329":9.1147356,"20230330":9.8027172,"20230331":12.16296,"20230401":20.1713328,"20230402":13.8546612,"20230403":13.614156,"20230404":13.3261848,"20230405":14.4423972,"20230406":9.3548844,"20230407":9.2103156,"20230408":14.1718572,"20230409":9.83178,"20230410":10.415466,"20230411":9.324882,"20230412":9.2289456,"20230413":9.2692836,"20230414":10.6124904,"20230415":15.8805036,"20230416":11.4660036,"20230417":11.595312,"20230418":9.5726772,"20230419":9.296856,"20230420":9.8377092,"20230421":10.5438024,"20230422":12.0156048,"20230423":10.1522808,"20230424":10.2995388,"20230425":9.040734,"20230426":9.9405144,"20230427":11.3861376,"20230428":15.4203264,"20230429":34.1897112,"20230430":33.2100324,"20230501":25.6317048,"20230502":16.12629,"20230503":12.6268308,"20230504":10.9954584,"20230505":8.5768956,"20230506":9.2377908,"20240123":9.0026316,"20240124":9.2261592,"20240125":9.9877536,"20240126":11.5594452,"20240127":14.9595012,"20240128":13.0896972,"20240129":13.3264116,"20240130":13.0963068,"20240131":14.4920664,"20240201":18.6778872,"20240202":19.126854,"20240203":23.1928272,"20240204":22.7346588,"20240205":21.672846,"20240206":21.4336044,"20240207":20.2001688,"20240208":17.147862,"20240209":13.968126,"20240210":7.138692,"20240211":9.3569256,"20240212":7.4546568,"20240213":6.5295072,"20240214":5.656554,"20240215":5.5979748,"20240216":5.1955992,"20240217":5.271804,"20240218":5.165856,"20240219":5.4766368,"20240220":5.480784,"20240221":5.7100788,"20240222":6.014736,"20240223":6.9849216,"20240224":11.374992,"2024022 ...
# ZhuHai: http://huiyan.baidu.com/migration/historycurve.json?dt=city&id=440400&type=move_out
#
# {"errno":0,"errmsg":"SUCCESS","data":{"list":{"20190112":1.9891332,"20190113":1.8537012,"20190114":1.8580104,"20190115":1.6851564,"20190116":1.7555616,"20190117":1.8052956,"20190118":1.8154368,"20190119":2.1011076,"20190120":1.9272816,"20190121":1.9795752,"20190122":1.9294524,"20190123":2.0616768,"20190124":2.1088512,"20190125":2.237544,"20190126":2.6898804,"20190127":2.607066,"20190128":2.6757864,"20190129":2.508408,"20190130":2.6077464,"20190131":2.9885112,"20190201":3.105054,"20190202":2.7797256,"20190203":2.3925132,"20190204":2.085912,"20190205":1.4742648,"20190206":2.076192,"20190207":2.009124,"20190208":2.070522,"20190209":1.9500912,"20190210":1.8575892,"20190211":1.75608,"20190212":1.6075908,"20190213":1.5729876,"20190214":1.6108632,"20190215":1.5266556,"20190216":1.7331084,"20190217":1.5849108,"20190218":1.549206,"20190219":1.3740192,"20190220":1.3370508,"20190221":1.36647,"20190222":1.4438088,"20190223":1.7720208,"20190224":1.6646796,"20190225":1.5504696,"20190226":1.416528,"20190227":1.5183288,"20190228":1.9391076,"20190301":1.7163576,"20190302":2.081214,"20190303":1.7285076,"20190304":1.781514,"20190305":1.48716,"20190306":1.5456096,"20190307":1.5486228,"20190308":1.709586,"20190309":1.9993068,"20230104":2.0695176,"20230105":2.0495916,"20230106":2.2061484,"20230107":2.5828956,"20230108":2.4067692,"20230109":2.4531012,"20230110":2.4829092,"20230111":2.6082,"20230112":2.6449092,"20230113":2.8079136,"20230114":3.4714656,"20230115":3.356154,"20230116":3.361338,"20230117":3.3814908,"20230118":3.6464256,"20230119":3.6055044,"20230120":3.0724596,"20230121":2.7050436,"20230122":1.6943256,"20230123":2.7198828,"20230124":2.35953,"20230125":2.370546,"20230126":2.3332536,"20230127":2.2489164,"20230128":1.9804176,"20230129":1.9606536,"20230130":2.0167704,"20230131":1.9603944,"20230201":1.99989,"20230202":2.0052036,"20230203":2.0524752,"20230204":2.4041124,"20230205":2.1065508,"20230206":2.2358592,"20230207":1.9747152,"20230208":1.916298,"20230209":1.9997928,"20230210":2.2548456,"20230211":2.8595268,"20230212":2.4373548,"20230213":2.5524072,"20230214":2.2374792,"20230215":2.1731652,"20230216":2.2504716,"20230217":2.510514,"20230218":3.1524228,"20230317":2.7557172,"20230318":3.4225092,"20230319":2.8193832,"20230320":2.8887192,"20230321":2.4169104,"20230322":2.2678056,"20230323":2.3307912,"20230324":2.6900424,"20230325":3.3144552,"20230326":2.3579748,"20230327":2.5075008,"20230328":2.222964,"20230329":2.2193676,"20230330":2.364228,"20230331":2.8693116,"20230401":3.6654768,"20230402":2.8052244,"20230403":2.9894832,"20230404":2.950992,"20230405":2.9252664,"20230406":2.1305268,"20230407":2.3674032,"20230408":2.974482,"20230409":2.3677272,"20230410":2.48346,"20230411":2.4236496,"20230412":2.2615848,"20230413":2.3227236,"20230414":2.753352,"20230415":3.3153948,"20230416":2.8150092,"20230417":2.8551852,"20230418":2.424006,"20230419":2.2853988,"20230420":2.353212,"20230421":2.5700004,"20230422":2.8543752,"20230423":2.5102548,"20230424":2.7548748,"20230425":2.3086296,"20230426":2.335068,"20230427":2.6564112,"20230428":3.2076324,"20230429":5.5019412,"20230430":4.7612124,"20230501":4.69395,"20230502":4.3418592,"20230503":3.915702,"20230504":2.862702,"20230505":2.3913468,"20230506":2.36034,"20240123":2.4313932,"20240124":2.3601456,"20240125":2.52153,"20240126":2.8130976,"20240127":3.1694976,"20240128":2.8455624,"20240129":3.059208,"20240130":2.926692,"20240131":2.9352456,"20240201":3.381588,"20240202":3.2444388,"20240203":3.575016,"20240204":3.6033012,"20240205":3.7474488,"20240206":3.6554652,"20240207":3.5775108,"20240208":3.3018516,"20240209":2.9294136,"20240210":1.9535256,"20240211":2.9933388,"20240212":2.7629424,"20240213":2.800494,"20240214":2.6922132,"20240215":2.7261684,"20240216":2.5449876,"20240217":2.4537492,"20240218":2.197368,"20240219":2.1702168,"20240220":1.9215468,"20240221":1.9534608,"20240222":2.0274624,"20240223":2.0909016,"20240224":2.56284,"20240225":2.1308184,"20240226":2.2175532,"20240227":1.9905588,"20240228":1.8387972, ...
# FoShan: http://huiyan.baidu.com/migration/historycurve.json?dt=city&id=440600&type=move_out
#
# {"errno":0,"errmsg":"SUCCESS","data":{"list":{"20190112":5.1826392,"20190113":4.9198104,"20190114":5.3702028,"20190115":4.7646792,"20190116":5.0008428,"20190117":5.7045708,"20190118":5.5135728,"20190119":6.0905844,"20190120":6.3982548,"20190121":7.2853344,"20190122":7.6090104,"20190123":8.1238788,"20190124":8.5901148,"20190125":9.2690892,"20190126":11.1303396,"20190127":11.2301316,"20190128":11.4410232,"20190129":10.1167704,"20190130":8.9109396,"20190131":8.9108748,"20190201":8.8668756,"20190202":7.3043856,"20190203":5.8425624,"20190204":4.6438272,"20190205":3.7173816,"20190206":5.6207196,"20190207":5.9905332,"20190208":5.0924052,"20190209":4.0574196,"20190210":3.4614216,"20190211":3.21327,"20190212":3.3544044,"20190213":3.3548256,"20190214":3.6575388,"20190215":3.5309196,"20190216":3.9716568,"20190217":3.8177892,"20190218":4.1413032,"20190219":3.6766872,"20190220":3.6571176,"20190221":3.7771272,"20190222":3.8359332,"20190223":4.6105848,"20190224":5.040306,"20190225":4.7971764,"20190226":4.05324,"20190227":4.4783604,"20190228":5.6690604,"20190301":4.9920948,"20190302":5.669028,"20190303":5.3849772,"20190304":5.8760964,"20190305":4.6295388,"20190306":4.456296,"20190307":4.8018744,"20190308":4.9653,"20190309":5.1761592,"20230104":6.9764004,"20230105":7.3657836,"20230106":8.5592376,"20230107":9.3403368,"20230108":9.3394296,"20230109":10.0009404,"20230110":9.8981028,"20230111":10.9519128,"20230112":11.1061692,"20230113":10.9254744,"20230114":11.7364788,"20230115":11.7521928,"20230116":11.9899764,"20230117":11.014704,"20230118":10.2162708,"20230119":9.6342048,"20230120":7.3691208,"20230121":5.9447196,"20230122":4.6789488,"20230123":7.9141536,"20230124":7.7687424,"20230125":6.577848,"20230126":5.5349244,"20230127":5.0614956,"20230128":4.6209204,"20230129":4.929012,"20230130":4.8154176,"20230131":5.0159412,"20230201":5.373054,"20230202":5.255928,"20230203":5.566158,"20230204":6.3050076,"20230205":5.8677048,"20230206":7.5434652,"20230207":5.753916,"20230208":5.647482,"20230209":6.4791576,"20230210":6.6025368,"20230211":8.1920808,"20230212":7.585974,"20230213":8.7469308,"20230214":6.784236,"20230215":6.67197,"20230216":7.5098664,"20230217":7.6057056,"20230218":9.3904596,"20230317":8.3742984,"20230318":10.525626,"20230319":9.234648,"20230320":9.7180884,"20230321":7.3065564,"20230322":6.744222,"20230323":7.3549296,"20230324":7.2558504,"20230325":8.6247504,"20230326":7.3446588,"20230327":8.6186916,"20230328":7.0067916,"20230329":6.5756124,"20230330":7.522308,"20230331":8.4261708,"20230401":11.2235544,"20230402":9.6309972,"20230403":11.6742384,"20230404":12.6166896,"20230405":10.710954,"20230406":7.6630536,"20230407":6.8508828,"20230408":8.493822,"20230409":7.3630944,"20230410":8.6385204,"20230411":6.9654492,"20230412":6.7736088,"20230413":7.2009324,"20230414":7.3244412,"20230415":9.0132912,"20230416":8.6275044,"20230417":9.6201432,"20230418":7.2209232,"20230419":6.5816712,"20230420":7.5993552,"20230421":7.475814,"20230422":7.5829608,"20230423":8.133696,"20230424":7.629552,"20230425":6.586434,"20230426":7.4506068,"20230427":7.4540736,"20230428":8.6472036,"20230429":15.08544,"20230430":19.102716,"20230501":19.8261108,"20230502":12.04875,"20230503":10.5647652,"20230504":9.0809424,"20230505":6.7487256,"20230506":6.857298,"20240123":6.8419404,"20240124":7.2394884,"20240125":8.3971728,"20240126":9.6047856,"20240127":10.8041364,"20240128":10.2764376,"20240129":11.4304608,"20240130":10.8040068,"20240131":11.0387448,"20240201":14.0221368,"20240202":12.2635944,"20240203":11.834748,"20240204":11.849328,"20240205":11.3724,"20240206":10.6022196,"20240207":9.475704,"20240208":7.4705652,"20240209":6.1655256,"20240210":4.9730436,"20240211":7.9646976,"20240212":7.9183656,"20240213":6.858594,"20240214":5.7296484,"20240215":5.3450928,"20240216":4.9100904,"20240217":4.9660776,"20240218":4.91184,"20240219":4.5823968,"20240220":4.588326,"20240221":4.9491648,"20240222":4.8880584,"20240223":5.1563628,"20240224":6.4309788,"20240225":6.2548848,"20240226":7.0475184 ...
# JiangMen: http://huiyan.baidu.com/migration/historycurve.json?dt=city&id=440700&type=move_out
#
# {"errno":0,"errmsg":"SUCCESS","data":{"list":{"20190112":1.2790224,"20190113":1.2291588,"20190114":1.3198788,"20190115":1.157652,"20190116":1.2103668,"20190117":1.2859884,"20190118":1.3689648,"20190119":1.6298172,"20190120":1.640574,"20190121":1.7717292,"20190122":1.7416944,"20190123":1.7977464,"20190124":1.8838656,"20190125":2.0167704,"20190126":2.3926428,"20190127":2.3470236,"20190128":2.3025384,"20190129":2.0319984,"20190130":1.8988992,"20190131":1.8689292,"20190201":1.87272,"20190202":1.626804,"20190203":1.3338756,"20190204":1.1033172,"20190205":1.1502648,"20190206":1.9347012,"20190207":2.5884684,"20190208":2.4119856,"20190209":2.434698,"20190210":2.3215896,"20190211":2.074734,"20190212":1.8459252,"20190213":1.5853644,"20190214":1.4443272,"20190215":1.2308112,"20190216":1.2642156,"20190217":1.1392488,"20190218":1.1031552,"20190219":0.895698,"20190220":0.9869688,"20190221":0.9611784,"20190222":0.997434,"20190223":1.2322692,"20190224":1.3539636,"20190225":1.1407392,"20190226":0.938628,"20190227":1.0314864,"20190228":1.3073724,"20190301":1.1987676,"20190302":1.4479236,"20190303":1.3281408,"20190304":1.341522,"20190305":1.036962,"20190306":0.9932544,"20190307":0.9973044,"20190308":1.1112552,"20190309":1.1946204,"20230104":1.603638,"20230105":1.6916364,"20230106":1.908846,"20230107":2.1344472,"20230108":2.1932532,"20230109":2.2274676,"20230110":2.2572432,"20230111":2.427732,"20230112":2.3744664,"20230113":2.4756516,"20230114":2.6526528,"20230115":2.6325,"20230116":2.590866,"20230117":2.3990904,"20230118":2.2170024,"20230119":2.0957292,"20230120":1.7392644,"20230121":1.5058224,"20230122":1.5457392,"20230123":2.9828736,"20230124":3.2627124,"20230125":3.1427352,"20230126":3.3193476,"20230127":3.1401432,"20230128":2.5047792,"20230129":2.3259636,"20230130":1.9881612,"20230131":1.769202,"20230201":1.689336,"20230202":1.5443136,"20230203":1.5180048,"20230204":1.6376256,"20230205":1.5947928,"20230206":1.9249812,"20230207":1.4428368,"20230208":1.4015592,"20230209":1.474524,"20230210":1.6453368,"20230211":2.0840652,"20230212":2.0216304,"20230213":2.0568168,"20230214":1.605906,"20230215":1.5783336,"20230216":1.6780284,"20230217":1.8690264,"20230218":2.4332724,"20230317":1.991952,"20230318":2.385612,"20230319":2.420928,"20230320":2.5300512,"20230321":1.7779824,"20230322":1.6187364,"20230323":1.689498,"20230324":1.8630324,"20230325":2.1572244,"20230326":1.8488736,"20230327":1.9690128,"20230328":1.5781716,"20230329":1.5004116,"20230330":1.5861096,"20230331":1.9188576,"20230401":2.5371468,"20230402":2.204334,"20230403":2.4482412,"20230404":2.4218676,"20230405":2.4624,"20230406":2.0461896,"20230407":1.8058788,"20230408":2.0287908,"20230409":1.8494892,"20230410":2.0364048,"20230411":1.610118,"20230412":1.6157556,"20230413":1.622106,"20230414":1.8013752,"20230415":2.2330728,"20230416":2.1266064,"20230417":2.1477312,"20230418":1.6720992,"20230419":1.5562044,"20230420":1.6649712,"20230421":1.8161496,"20230422":1.8422964,"20230423":1.80792,"20230424":1.7859852,"20230425":1.5669288,"20230426":1.6436196,"20230427":1.6905996,"20230428":2.1007836,"20230429":3.6924984,"20230430":4.5500616,"20230501":5.2621812,"20230502":4.4671176,"20230503":4.3107552,"20230504":2.6785404,"20230505":1.6823052,"20230506":1.7206344,"20240123":1.6550568,"20240124":1.7216064,"20240125":1.9277352,"20240126":2.31174,"20240127":2.6084916,"20240128":2.5435944,"20240129":2.6777952,"20240130":2.4229368,"20240131":2.5718472,"20240201":3.1116636,"20240202":2.7589896,"20240203":2.7046548,"20240204":2.6485056,"20240205":2.5729812,"20240206":2.4186276,"20240207":2.1391452,"20240208":1.7448696,"20240209":1.540296,"20240210":1.6354872,"20240211":3.0297888,"20240212":3.5643888,"20240213":3.3595884,"20240214":3.3319188,"20240215":3.1883544,"20240216":2.8433916,"20240217":2.6347032,"20240218":2.0546784,"20240219":1.6346772,"20240220":1.4301684,"20240221":1.4217444,"20240222":1.317546,"20240223":1.4172732,"20240224":1.8284616,"20240225":1.8640692,"20240226":1.7778204,"20240227":1.3368564,"20 ...
# ZhaoQing: http://huiyan.baidu.com/migration/historycurve.json?dt=city&id=441200&type=move_out
#
# {"errno":0,"errmsg":"SUCCESS","data":{"list":{"20190112":1.04571,"20190113":0.9659088,"20190114":0.9977904,"20190115":0.8959248,"20190116":1.0104912,"20190117":1.0273392,"20190118":1.1621556,"20190119":1.3156668,"20190120":1.197018,"20190121":1.2377124,"20190122":1.2044376,"20190123":1.2194388,"20190124":1.3163148,"20190125":1.3867524,"20190126":1.4810364,"20190127":1.3858452,"20190128":1.3736628,"20190129":1.250802,"20190130":1.2381336,"20190131":1.186812,"20190201":1.1632248,"20190202":1.0295424,"20190203":0.9424836,"20190204":0.7769844,"20190205":0.8003448,"20190206":1.7841384,"20190207":2.1832416,"20190208":2.5254828,"20190209":2.8308852,"20190210":3.185892,"20190211":3.0982824,"20190212":3.3061608,"20190213":2.6084592,"20190214":2.407644,"20190215":2.0377656,"20190216":1.874016,"20190217":1.4587128,"20190218":1.1645532,"20190219":0.9077184,"20190220":1.2693996,"20190221":1.1675664,"20190222":1.0643724,"20190223":1.1340972,"20190224":1.2490848,"20190225":1.0396836,"20190226":0.8242884,"20190227":0.9303984,"20190228":1.1036412,"20190301":1.0028772,"20190302":1.1810772,"20190303":1.0266588,"20190304":1.0678392,"20190305":0.8452836,"20190306":0.7664868,"20190307":0.7532028,"20190308":0.9143604,"20190309":1.0344672,"20230104":1.1932596,"20230105":1.2379392,"20230106":1.373112,"20230107":1.5212448,"20230108":1.4968152,"20230109":1.5896088,"20230110":1.4981112,"20230111":1.588734,"20230112":1.5567552,"20230113":1.6333488,"20230114":1.6527564,"20230115":1.6004628,"20230116":1.6145244,"20230117":1.4880996,"20230118":1.4354172,"20230119":1.37538,"20230120":1.221966,"20230121":1.0024884,"20230122":0.95175,"20230123":2.6961012,"20230124":2.972538,"20230125":3.6412092,"20230126":4.0275792,"20230127":4.41693,"20230128":3.496122,"20230129":4.0275468,"20230130":3.11364,"20230131":2.782026,"20230201":2.4607476,"20230202":2.091744,"20230203":1.8076932,"20230204":1.6095348,"20230205":1.4663916,"20230206":2.0722716,"20230207":1.593594,"20230208":1.3819248,"20230209":1.2768192,"20230210":1.3893768,"20230211":1.7539092,"20230212":1.6581672,"20230213":1.5946632,"20230214":1.2591936,"20230215":1.290978,"20230216":1.2745188,"20230217":1.5488496,"20230218":2.0142432,"20230317":1.7007408,"20230318":2.0794968,"20230319":1.951776,"20230320":1.8889848,"20230321":1.3288536,"20230322":1.2086172,"20230323":1.212084,"20230324":1.4354496,"20230325":1.6466652,"20230326":1.4262804,"20230327":1.5840036,"20230328":1.226016,"20230329":1.1489688,"20230330":1.2140604,"20230331":1.5457068,"20230401":1.813266,"20230402":1.6663968,"20230403":1.9821024,"20230404":1.9989828,"20230405":2.119284,"20230406":3.916674,"20230407":3.0380832,"20230408":2.181168,"20230409":1.8875592,"20230410":1.9049904,"20230411":1.3359168,"20230412":1.2509964,"20230413":1.2560184,"20230414":1.5220224,"20230415":1.8507528,"20230416":1.7132796,"20230417":1.795932,"20230418":1.2760092,"20230419":1.1988,"20230420":1.2215772,"20230421":1.4078448,"20230422":1.4583564,"20230423":1.3467384,"20230424":1.3109364,"20230425":1.1708064,"20230426":1.2032712,"20230427":1.3094784,"20230428":2.1343824,"20230429":3.245508,"20230430":3.122712,"20230501":3.65391,"20230502":4.0293936,"20230503":4.67775,"20230504":2.610792,"20230505":1.4941584,"20230506":1.392228,"20240123":1.2991428,"20240124":1.3446,"20240125":1.4532048,"20240126":1.747494,"20240127":1.894752,"20240128":1.9984644,"20240129":1.9698552,"20240130":1.7889984,"20240131":1.9629864,"20240201":1.9275732,"20240202":1.7534556,"20240203":1.6675632,"20240204":1.5596064,"20240205":1.5590232,"20240206":1.4946444,"20240207":1.3713948,"20240208":1.2366756,"20240209":1.1104128,"20240210":1.1133612,"20240211":2.8854468,"20240212":3.149928,"20240213":3.8605896,"20240214":4.168584,"20240215":4.4405172,"20240216":3.888486,"20240217":4.300614,"20240218":3.3811668,"20240219":2.6032752,"20240220":2.0532204,"20240221":1.7480772,"20240222":1.4990832,"20240223":1.4167224,"20240224":1.5957648,"20240225":2.029698,"20240226":1.7524512,"20240227":1.2492468,"20240228":1.17631 ...
# HuiZhou: http://huiyan.baidu.com/migration/historycurve.json?dt=city&id=441300&type=move_out
#
# {"errno":0,"errmsg":"SUCCESS","data":{"list":{"20190112":2.7631692,"20190113":2.8114776,"20190114":3.0999672,"20190115":2.4467184,"20190116":2.6025624,"20190117":2.728242,"20190118":2.7691308,"20190119":3.1685904,"20190120":3.3628932,"20190121":3.9055608,"20190122":3.493206,"20190123":3.7318968,"20190124":3.9946932,"20190125":4.4828964,"20190126":5.3432784,"20190127":5.4225288,"20190128":5.4407052,"20190129":4.8336588,"20190130":4.76928,"20190131":4.9870728,"20190201":4.8897108,"20190202":4.1150592,"20190203":3.2237028,"20190204":2.5706484,"20190205":2.074086,"20190206":4.1232564,"20190207":3.8110824,"20190208":3.8012004,"20190209":3.7155672,"20190210":3.8494116,"20190211":3.5853516,"20190212":3.08205,"20190213":2.768742,"20190214":2.699406,"20190215":2.377998,"20190216":2.5202664,"20190217":2.5204608,"20190218":2.7644652,"20190219":1.9396908,"20190220":1.9906236,"20190221":2.041362,"20190222":2.0278836,"20190223":2.5412616,"20190224":2.834352,"20190225":2.7910656,"20190226":2.0660508,"20190227":2.2836816,"20190228":2.8185732,"20190301":2.4800256,"20190302":3.0092472,"20190303":2.9848824,"20190304":3.3564456,"20190305":2.2606128,"20190306":2.141802,"20190307":2.24127,"20190308":2.4689448,"20190309":2.68758,"20230104":3.735234,"20230105":3.961224,"20230106":4.5108576,"20230107":4.7669472,"20230108":5.1546456,"20230109":5.8925232,"20230110":5.055696,"20230111":5.6767392,"20230112":5.9543424,"20230113":5.941188,"20230114":6.8429124,"20230115":7.1469216,"20230116":7.1197704,"20230117":6.2430588,"20230118":5.6441772,"20230119":5.49504,"20230120":4.4481312,"20230121":3.5914752,"20230122":2.9244888,"20230123":6.2889048,"20230124":5.1163164,"20230125":5.334984,"20230126":5.3969004,"20230127":5.5603584,"20230128":4.8944736,"20230129":4.5046044,"20230130":4.1124672,"20230131":3.9177756,"20230201":3.790152,"20230202":3.526092,"20230203":3.7360116,"20230204":4.0494492,"20230205":4.1246172,"20230206":5.3867592,"20230207":3.2887944,"20230208":3.1335336,"20230209":3.639168,"20230210":3.679668,"20230211":4.5629568,"20230212":4.9746636,"20230213":5.6925504,"20230214":3.6252684,"20230215":3.6026208,"20230216":4.0836636,"20230217":4.1383872,"20230218":5.17266,"20230317":4.4052012,"20230318":5.3927856,"20230319":5.8002156,"20230320":6.2395272,"20230321":3.7934568,"20230322":3.5412228,"20230323":4.0554432,"20230324":4.1302224,"20230325":4.74417,"20230326":4.60485,"20230327":5.5568592,"20230328":3.5269992,"20230329":3.5265132,"20230330":4.1210208,"20230331":4.5386568,"20230401":5.906844,"20230402":5.495202,"20230403":6.3162828,"20230404":4.930956,"20230405":4.9096044,"20230406":4.97664,"20230407":3.7850004,"20230408":4.3022988,"20230409":4.7452392,"20230410":5.6090232,"20230411":3.7514664,"20230412":3.6947988,"20230413":4.0429044,"20230414":4.133268,"20230415":4.9124232,"20230416":5.3676756,"20230417":6.1087284,"20230418":3.824334,"20230419":3.4989408,"20230420":3.9701016,"20230421":3.9416544,"20230422":4.0893984,"20230423":4.7427444,"20230424":4.4984808,"20230425":3.5080776,"20230426":3.9748644,"20230427":4.117878,"20230428":4.9522752,"20230429":8.2860408,"20230430":9.710442,"20230501":10.4432328,"20230502":10.9432296,"20230503":10.1463192,"20230504":6.5538072,"20230505":4.00464,"20230506":3.9232188,"20240123":3.8371968,"20240124":3.9346236,"20240125":4.634658,"20240126":5.0327244,"20240127":5.3933364,"20240128":5.4992844,"20240129":6.472386,"20240130":5.3847504,"20240131":5.9149116,"20240201":7.5870432,"20240202":6.5841336,"20240203":6.780996,"20240204":6.8748588,"20240205":6.5310948,"20240206":6.2108208,"20240207":5.7278016,"20240208":4.6277568,"20240209":3.8354472,"20240210":3.2209488,"20240211":6.5578896,"20240212":5.421006,"20240213":5.4017928,"20240214":5.2420932,"20240215":5.2712208,"20240216":5.0770476,"20240217":5.0967792,"20240218":4.5392724,"20240219":3.6545904,"20240220":3.130812,"20240221":3.1766904,"20240222":3.064068,"20240223":3.2986116,"20240224":4.0194468,"20240225":4.4440812,"20240226":5.0523264,"20240227":3.1024296,"20240228":2 ...
# DongGuan: http://huiyan.baidu.com/migration/historycurve.json?dt=city&id=441900&type=move_out
#
# {"errno":0,"errmsg":"SUCCESS","data":{"list":{"20190112":6.1890804,"20190113":6.009066,"20190114":5.7869964,"20190115":5.2461108,"20190116":5.6386368,"20190117":6.0716628,"20190118":6.12846,"20190119":7.1353872,"20190120":7.7012532,"20190121":8.2592784,"20190122":8.4792096,"20190123":9.2722644,"20190124":10.01403,"20190125":11.6556084,"20190126":16.2433188,"20190127":18.6978132,"20190128":17.7327144,"20190129":15.7135788,"20190130":15.0245604,"20190131":14.6175192,"20190201":13.7359152,"20190202":10.580382,"20190203":6.978474,"20190204":5.040306,"20190205":3.5153676,"20190206":4.6025172,"20190207":4.7830176,"20190208":3.8656764,"20190209":3.2480352,"20190210":2.8983096,"20190211":2.798712,"20190212":2.8855764,"20190213":3.0011148,"20190214":3.3074892,"20190215":3.5107668,"20190216":4.2880104,"20190217":4.378374,"20190218":4.3606512,"20190219":3.8731284,"20190220":3.7784556,"20190221":3.9103236,"20190222":4.0855104,"20190223":5.1975108,"20190224":5.8124628,"20190225":4.9275216,"20190226":4.3307136,"20190227":4.9455684,"20190228":5.9178276,"20190301":5.27067,"20190302":6.493446,"20190303":6.3717192,"20190304":6.0484968,"20190305":4.8267252,"20190306":4.7400876,"20190307":4.7706732,"20190308":5.1587604,"20190309":5.8219884,"20230104":7.9938252,"20230105":8.2287252,"20230106":9.2907324,"20230107":10.852542,"20230108":11.1722976,"20230109":11.3507568,"20230110":12.1760172,"20230111":14.6684196,"20230112":15.4319256,"20230113":16.7717628,"20230114":21.4837272,"20230115":22.2655716,"20230116":18.6500232,"20230117":15.7479552,"20230118":12.8941956,"20230119":10.8863352,"20230120":7.609626,"20230121":6.1240212,"20230122":4.1542632,"20230123":6.0200496,"20230124":6.0453864,"20230125":4.7674656,"20230126":4.0680144,"20230127":3.7608624,"20230128":3.5490636,"20230129":3.9288888,"20230130":4.1999796,"20230131":4.4822484,"20230201":4.9639068,"20230202":5.1798204,"20230203":5.7593268,"20230204":7.0635564,"20230205":6.9692076,"20230206":7.1652924,"20230207":5.8748652,"20230208":6.0289596,"20230209":6.310386,"20230210":6.9377796,"20230211":9.2521764,"20230212":8.6406912,"20230213":8.5926096,"20230214":7.1010756,"20230215":7.1427744,"20230216":7.4224188,"20230217":7.9840728,"20230218":10.4876532,"20230317":8.66133,"20230318":11.57652,"20230319":10.0611072,"20230320":9.4027068,"20230321":7.4666124,"20230322":7.22115,"20230323":7.655796,"20230324":8.1339552,"20230325":9.9956916,"20230326":8.1483408,"20230327":8.7561,"20230328":7.5184848,"20230329":7.5937176,"20230330":8.28387,"20230331":9.577116,"20230401":13.9667004,"20230402":11.6779644,"20230403":11.4581952,"20230404":10.8666684,"20230405":11.8282356,"20230406":7.9167132,"20230407":7.2931752,"20230408":9.4214988,"20230409":7.9265304,"20230410":8.3866104,"20230411":7.3051308,"20230412":7.3383408,"20230413":7.593102,"20230414":8.0641656,"20230415":10.546524,"20230416":9.530784,"20230417":9.4829616,"20230418":7.6581612,"20230419":7.1372988,"20230420":7.7248404,"20230421":8.0281044,"20230422":8.6774652,"20230423":8.6079348,"20230424":7.9584444,"20230425":7.094952,"20230426":7.7629428,"20230427":8.1596484,"20230428":10.2178584,"20230429":20.9660076,"20230430":24.1784028,"20230501":19.6244856,"20230502":12.5215308,"20230503":10.289754,"20230504":8.8456536,"20230505":7.1108604,"20230506":7.5584016,"20240123":7.2164844,"20240124":7.6219704,"20240125":8.7680232,"20240126":10.544256,"20240127":11.943774,"20240128":11.9370996,"20240129":12.3426828,"20240130":12.1794192,"20240131":14.3237808,"20240201":21.6333504,"20240202":19.363374,"20240203":20.7594576,"20240204":19.8901656,"20240205":16.4131596,"20240206":14.0227524,"20240207":11.4728724,"20240208":8.1806112,"20240209":6.624666,"20240210":4.2784524,"20240211":5.8548744,"20240212":5.9898204,"20240213":4.8621384,"20240214":4.159836,"20240215":3.8241072,"20240216":3.6596124,"20240217":3.7910268,"20240218":3.9715596,"20240219":4.1248116,"20240220":4.3959996,"20240221":4.789854,"20240222":4.9078224,"20240223":5.4767988,"20240224":7.5187764,"20240225":6.597 ...
# ZhongShan: http://huiyan.baidu.com/migration/historycurve.json?dt=city&id=442000&type=move_out
#
# {"errno":0,"errmsg":"SUCCESS","data":{"list":{"20190112":2.5137216,"20190113":2.4733188,"20190114":2.804868,"20190115":2.413476,"20190116":2.605284,"20190117":2.9253312,"20190118":2.8290384,"20190119":3.140694,"20190120":3.3044436,"20190121":3.8536884,"20190122":3.9249684,"20190123":4.2038352,"20190124":4.4482608,"20190125":4.7300112,"20190126":6.0188832,"20190127":6.3735336,"20190128":6.3712008,"20190129":5.6482272,"20190130":5.1402924,"20190131":5.195502,"20190201":5.0533308,"20190202":3.9809556,"20190203":2.9102976,"20190204":2.289708,"20190205":1.9553076,"20190206":2.7760968,"20190207":2.791422,"20190208":2.4446448,"20190209":1.986282,"20190210":1.7524836,"20190211":1.6777692,"20190212":1.7357004,"20190213":1.6610832,"20190214":1.738746,"20190215":1.7613936,"20190216":1.931202,"20190217":1.9344744,"20190218":2.1413808,"20190219":1.8453744,"20190220":1.8129744,"20190221":1.9304892,"20190222":1.934604,"20190223":2.207574,"20190224":2.4717636,"20190225":2.4532632,"20190226":2.0748312,"20190227":2.243376,"20190228":2.8034748,"20190301":2.4877044,"20190302":2.7778464,"20190303":2.619216,"20190304":3.0054888,"20190305":2.297322,"20190306":2.130138,"20190307":2.3127768,"20190308":2.4311988,"20190309":2.5559712,"20230104":3.4589268,"20230105":3.7103508,"20230106":4.4176428,"20230107":4.7271924,"20230108":4.801842,"20230109":5.316678,"20230110":5.1489108,"20230111":5.893074,"20230112":6.1812396,"20230113":6.0999156,"20230114":6.7962564,"20230115":7.071462,"20230116":6.9751044,"20230117":5.995134,"20230118":5.3313552,"20230119":4.751784,"20230120":3.4943724,"20230121":2.843424,"20230122":2.581794,"20230123":3.830814,"20230124":3.3476976,"20230125":2.9853684,"20230126":2.6224236,"20230127":2.373462,"20230128":2.291328,"20230129":2.4259176,"20230130":2.4179472,"20230131":2.42595,"20230201":2.5751844,"20230202":2.5700652,"20230203":2.689362,"20230204":2.9768148,"20230205":3.0400272,"20230206":3.78189,"20230207":2.815398,"20230208":2.7304776,"20230209":3.1705344,"20230210":3.205818,"20230211":3.8267964,"20230212":3.7795572,"20230213":4.3753284,"20230214":3.2858784,"20230215":3.1986576,"20230216":3.6766548,"20230217":3.5846712,"20230218":4.2572304,"20230317":3.8328552,"20230318":4.55058,"20230319":4.3498296,"20230320":4.8190788,"20230321":3.5666892,"20230322":3.3268968,"20230323":3.718224,"20230324":3.6047592,"20230325":4.0441356,"20230326":3.4309332,"20230327":4.2494544,"20230328":3.3910164,"20230329":3.1503492,"20230330":3.6949932,"20230331":3.9528324,"20230401":5.1664068,"20230402":4.7476692,"20230403":5.7065796,"20230404":5.7193776,"20230405":5.3737668,"20230406":4.0271256,"20230407":3.3541452,"20230408":3.8137068,"20230409":3.4725672,"20230410":4.2804612,"20230411":3.4231572,"20230412":3.3364872,"20230413":3.668976,"20230414":3.593808,"20230415":4.2714864,"20230416":4.1539392,"20230417":4.68747,"20230418":3.4739604,"20230419":3.1540752,"20230420":3.6726372,"20230421":3.582792,"20230422":3.603204,"20230423":4.0013676,"20230424":3.7653984,"20230425":3.2159592,"20230426":3.6450648,"20230427":3.6599364,"20230428":4.00869,"20230429":6.952878,"20230430":9.2046456,"20230501":10.1329704,"20230502":6.340518,"20230503":5.2616952,"20230504":4.5836604,"20230505":3.4391628,"20230506":3.418848,"20240123":3.3983064,"20240124":3.6648612,"20240125":4.3706628,"20240126":4.9330944,"20240127":5.450166,"20240128":5.2999272,"20240129":6.042924,"20240130":5.6036772,"20240131":5.963544,"20240201":8.1451332,"20240202":7.0903836,"20240203":6.951744,"20240204":7.0077312,"20240205":6.4541772,"20240206":5.6171556,"20240207":4.674348,"20240208":3.5689248,"20240209":2.9666088,"20240210":2.6631504,"20240211":4.005612,"20240212":3.553308,"20240213":3.2741172,"20240214":2.77425,"20240215":2.5952076,"20240216":2.4813864,"20240217":2.5896024,"20240218":2.5937172,"20240219":2.4663528,"20240220":2.412018,"20240221":2.5720092,"20240222":2.5547724,"20240223":2.6929908,"20240224":3.3310764,"20240225":3.1780836,"20240226":3.7145304,"20240227":2.713986,"20240228":2.6735832," ...
# Completed!
